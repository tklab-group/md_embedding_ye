# %%
import sys
sys.path.append('../../')
from data.data_divider import DataDivider
from data.util import get_module_data, get_method_map


def build_word_id_map(method_map):
    word_to_id = {}
    id_to_word = {}
    for i in range(len(method_map)):
        word = method_map[i]['item']
        word_id = method_map[i]['index']
        word_to_id[word] = word_id
        id_to_word[word_id] = word
    return word_to_id, id_to_word


git_name = 'LCExtractor'
module_data = get_module_data(git_name)
# method_map = get_method_map(git_name)
my_word_to_id, my_id_to_word = build_word_id_map(get_method_map(git_name))
# print(module_data)
# print(my_word_to_id)
# print(my_id_to_word)
# print(method_map)
print('size', len(module_data))
for i in range(len(module_data)):
    module_data_list = module_data[i]['list']
    show_array = []
    for j in range(len(module_data_list)):
        item = module_data_list[j]
        show_array.append(my_id_to_word[item])
    print(show_array)
# Out:
# size 100
# ['src/tklab/hagward/lcextractor/scm/GitReader#private_List[DiffEntry]_getCommitChanges(RevCommit_commit)']
# []
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_double_getMrr()', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_void_setMrr(double_mrr)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_getAveragePreventionPredictionScore(Set[Integer]_commit,List[AssociationRule]_rules,Set[Integer]_deleteset)']
# ['src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRStringForTemporaryFile(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_List[AssociationRule]_getLogicalCouplingThrouthTemporaryFile(List[Set[Integer]]_items,double_minSupport,double_minConfidence,int_start,int_stop)']
# []
# ['src/tklab/hagward/lcextractor/coupling/Predictor#private_List[Score]_predictPreventionWithCommitAggregation()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_int_getStopCommitIndexForCommitAggregation(int_startCommitIndex)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_void_convertRepositoryReaderResultToAggregatedTransaction()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_AggregatedTransaction_getAggregatedTransaction()', 'src/tklab/hagward/lcextractor/scm/AggregatedTransaction#public_AggregatedTransaction()', 'src/tklab/hagward/lcextractor/scm/AggregatedTransaction#public_void_addToLastChangeset(Set[Integer]_changeset)', 'src/tklab/hagward/lcextractor/scm/AggregatedTransaction#public_void_addToLastDeleteset(Set[Integer]_deleteset)', 'src/tklab/hagward/lcextractor/scm/AggregatedTransaction#public_void_addToLastTransaction(Commit_commit)', 'src/tklab/hagward/lcextractor/scm/AggregatedTransaction#public_void_newChangeset()', 'src/tklab/hagward/lcextractor/scm/AggregatedTransaction#public_void_newDeleteset()', 'src/tklab/hagward/lcextractor/scm/AggregatedTransaction#public_void_newTransaction()']
# ['src/tklab/hagward/lcextractor/coupling/AverageScore#public_AverageScore()', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_List[Integer]_getRanksList()', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_List[Integer]_getRecommendationsList()', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_void_setRanksList(List[Integer]_ranksList)', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_void_setRecommendationsList(List[Integer]_recommendationsList)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_getAveragePreventionPredictionScore(Set[Integer]_commit,List[AssociationRule]_rules,Set[Integer]_deleteset)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_Score_getPreventionPredictionScore(Set[Integer]_source,int_target,List[AssociationRule]_rules,Set[Integer]_deleteset)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_[T]_Collector[T,LinkedHashSet[T],LinkedHashSet[T]]_toLinkedHashSet()', 'src/tklab/hagward/lcextractor/coupling/Score#public_Score()', 'src/tklab/hagward/lcextractor/coupling/Score#public_int_getRank()', 'src/tklab/hagward/lcextractor/coupling/Score#public_int_getRecommendations()', 'src/tklab/hagward/lcextractor/coupling/Score#public_void_setRank(int_rank)', 'src/tklab/hagward/lcextractor/coupling/Score#public_void_setRecommendations(int_recommendations)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_Predictor_setupPredictor(long[]_time)', 'src/tklab/hagward/lcextractor/cli/Predict#private_void_addCmdOptions(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_AverageScore()', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_double_getPredictedRecall()', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_void_setPredictedRecall(double_meanPredictedRecall)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_getAveragePreventionPredictionScore(Set[Integer]_commit,List[AssociationRule]_rules,Set[Integer]_deleteset)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_List[Score]_predictPrevention()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_Score_getPreventionPredictionScore(Set[Integer]_source,int_target,List[AssociationRule]_rules,Set[Integer]_deleteset)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_List[double[]]_applyPrediction()']
# ['src/tklab/hagward/lcextractor/coupling/Predictor#public_Score_getOmissionPredictionScore(Set[Integer]_commit,Set[Integer]_omission,List[AssociationRule]_rules,Set[Integer]_deleteset)']
# ['src/tklab/hagward/lcextractor/coupling/Predictor#public_Score_getOmissionPredictionScore(Set[Integer]_commit,Set[Integer]_omission,List[AssociationRule]_rules,Set[Integer]_deleteset)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_Predictor_setupPredictor(long[]_time)', 'src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_List[Score]_predictOmission()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_List[double[]]_applyPrediction()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Score_getOmissionPredictionScore(Set[Integer]_commit,Set[Integer]_omission,List[AssociationRule]_rules,Set[Integer]_deleteset)', 'src/tklab/hagward/lcextractor/coupling/Score#public_Score()', 'src/tklab/hagward/lcextractor/coupling/Score#public_double_getRecall()', 'src/tklab/hagward/lcextractor/coupling/Score#public_void_setRecall(double_recall)', 'src/tklab/hagward/lcextractor/scm/Commit#public_Commit(RevCommit_revCommit)', 'src/tklab/hagward/lcextractor/scm/Commit#public_Commit(String_name,String_message,String_author,int_time)', 'src/tklab/hagward/lcextractor/scm/Commit#public_String_getAuthor()', 'src/tklab/hagward/lcextractor/scm/Commit#public_int_getTime()', 'src/tklab/hagward/lcextractor/cli/DBTools#private_RepositoryReaderResult_readResult(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBHandler#private_void_initTables(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBTools#private_void_writeResult(Connection_connection,RepositoryReaderResult_result)']
# ['src/tklab/hagward/lcextractor/coupling/LCExtractor#private_void_sortRules(List[AssociationRule]_rules)']
# ['src/tklab/hagward/lcextractor/coupling/LCExtractor#public_void_setSortBy(String_sortBy)']
# ['src/tklab/hagward/lcextractor/cli/Main#private_void_initialize(String_vcs,String_path)', 'src/tklab/hagward/lcextractor/cli/Main#private_void_parseArguments(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predict#private_Predictor_setupPredictor(long[]_time)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_void_sortRules(List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_LCExtractor()', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_SortBy_getSortBy()', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_void_setSortBy(String_sortBy)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_predictFixed()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_List[double[]]_predictVariable()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_AverageScore()', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_double_getFeedback()', 'src/tklab/hagward/lcextractor/coupling/AverageScore#public_void_setFeedback(double_feedback)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_predictFixed()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_List[double[]]_predictVariable()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_List[double[]]_applyPrediction()', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/coupling/Score#public_Score()', 'src/tklab/hagward/lcextractor/coupling/Score#public_double_getCoverage()', 'src/tklab/hagward/lcextractor/coupling/Score#public_double_getPrecision()', 'src/tklab/hagward/lcextractor/coupling/Score#public_int_getRuleSize()', 'src/tklab/hagward/lcextractor/coupling/Score#public_void_setCoverage(double_coverage)', 'src/tklab/hagward/lcextractor/coupling/Score#public_void_setPrecision(double_precision)', 'src/tklab/hagward/lcextractor/coupling/Score#public_void_setRuleSize(int_ruleSize)']
# ['src/tklab/hagward/lcextractor/cli/ArgumentParser#public_String_getUsageString()', 'src/tklab/hagward/lcextractor/cli/Main#private_void_initialize(String_vcs,String_path)', 'src/tklab/hagward/lcextractor/cli/Predict#private_Predictor_setupPredictor(long[]_time)', 'src/tklab/hagward/lcextractor/cli/Predict#private_void_addCmdOptions(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_LCExtractor()', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_boolean_isExcludeBigCommits()', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)']
# ['src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)']
# ['src/tklab/hagward/lcextractor/coupling/Predictor#private_Set[Integer]_toSetOfInteger(int[]_arrayOfInt)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)']
# ['src/tklab/hagward/lcextractor/coupling/Predictor#private_Set[Integer]_toSetOfInteger(int[]_arrayOfInt)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)']
# ['src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)']
# []
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_Predictor_setupPredictor(long[]_time)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_int_getStopCommitIndex(int_startCommitIndex)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)']
# ['src/tklab/hagward/lcextractor/cli/ArgumentParser#public_String_getUsageString()', 'src/tklab/hagward/lcextractor/cli/Predict#private_Predictor_setupPredictor(long[]_time)', 'src/tklab/hagward/lcextractor/cli/Predict#private_void_addCmdOptions(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_List[double[]]_predictVariable()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_predictFixed()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_int_getStopCommitIndex(int_startCommitIndex)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_int_getMiningCommits()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setMiningCommits(int_miningCommits)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)']
# ['src/tklab/hagward/lcextractor/coupling/Predictor#private_List[double[]]_predictVariable()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_Set[Integer]_getDeleteset(List[Set[Integer]]_deletesets,int_index)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/scm/GitReader#private_boolean_processCommit(RevCommit_commit,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/scm/GitReader#private_void_processDiffEntry(DiffEntry_diffEntry,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_addToLastDeleteset(String_path)', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_newDeleteset()']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)']
# []
# ['src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)']
# ['src/tklab/hagward/lcextractor/cli/Predict#private_Predictor_setupPredictor(long[]_time)', 'src/tklab/hagward/lcextractor/cli/Predict#private_void_addCmdOptions(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predict#private_void_predict(Predictor_predictor,long[]_time)', 'src/tklab/hagward/lcextractor/cli/Predict#private_void_printVerbose(String_msg)', 'src/tklab/hagward/lcextractor/cli/Predict#public_Predict(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_predictFixed()', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_void_setRemoved(T_item)']
# ['src/tklab/hagward/lcextractor/ArgumentParser#public_void_parse(String[]_args)']
# ['src/tklab/hagward/lcextractor/scm/MappedList#public_void_setReplaced(T_oldItem,T_newItem)']
# ['src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_boolean_isExcludeEmpty()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setExcludeEmpty(boolean_excludeEmpty)']
# ['src/tklab/hagward/lcextractor/scm/GitReader#private_boolean_processCommit(RevCommit_commit,RepositoryReaderResult_result)']
# ['src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)']
# []
# []
# ['src/tklab/hagward/lcextractor/ArgumentParser#public_void_addOption(String_name,String_descr,String_init)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_LCExtractor()', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_RepositoryReaderResult_getFilesFromAllCommits()', 'src/tklab/hagward/lcextractor/RepositoryReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)']
# ['src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_List[double[]]_predictVariable()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_predictFixed()', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_void_sortRules(List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_SortBy_getRuleSorting()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setRuleSorting(SortBy_ruleSorting)']
# ['src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_int_getMaxRules()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setMaxRules(int_maxRules)']
# ['src/tklab/hagward/lcextractor/cli/ArgumentParser#public_String[]_getArgAsStringArray(String_name)', 'src/tklab/hagward/lcextractor/cli/Main#private_void_initialize(String_vcs,String_path)', 'src/tklab/hagward/lcextractor/cli/Main#private_void_parseArguments(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_predictFixed()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_int_getNumRules()', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_boolean_applyFilter(String_msg)', 'src/tklab/hagward/lcextractor/RepositoryReader#public_void_addMessageFilter(String_filter)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_void_clearMessageFilters()']
# ['src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_List[double[]]_predictVariable()', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_boolean_setContains(Set[Integer]_changeset,int[]_items)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_AverageScore_predictFixed()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_List[double[]]_applyPrediction()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Mode_getMode()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/cli/Predictor#public_RepositoryReaderResult_getData()', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_double_getMinConfidence()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_double_getMinSupport()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_double_getTrainingDataRatio()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_int_getEndCommitIndex()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_int_getStartCommitIndex()', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_int_getWindowSize()', 'src/tklab/hagward/lcextractor/cli/Predictor#public_void_printDebug(String_s)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setEndCommitIndex(int_endCommitIndex)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setMinConfidence(double_minConfidence)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setMinSupport(double_minSupport)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setMode(Mode_mode)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setStartCommitIndex(int_startCommitIndex)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setTrainingDataRatio(double_trainingDataRatio)', 'src/tklab/hagward/lcextractor/coupling/Predictor#public_void_setWindowSize(int_windowSize)', 'src/tklab/hagward/lcextractor/cli/DBTools#private_RepositoryReaderResult_readResult(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBHandler#private_void_initTables(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBTools#private_void_writeResult(Connection_connection,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/cli/DBTools#public_RepositoryReaderResult_repositoryReaderResultFromDb(String_dbName)', 'src/tklab/hagward/lcextractor/scm/DBTools#public_void_storeRepositoryReaderResult(RepositoryReaderResult_result,String_dbName)']
# ['src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/cli/DBTools#private_void_writeResult(Connection_connection,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/cli/Predictor#List[double[]]_predictContinuous(int_from,int_to,int_step,double_minSupport,double_minConfidence,boolean_average)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_boolean_setContains(Set[Integer]_changeset,int[]_items)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predictor#public_void_printDebug(String_s)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)']
# ['src/tklab/hagward/lcextractor/cli/CommitRetriever#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/DBTools#private_RepositoryReaderResult_readResult(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBHandler#private_void_initTables(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBTools#private_void_writeResult(Connection_connection,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/cli/DBTools#public_RepositoryReaderResult_repositoryReaderResultFromDb(String_dbName)', 'src/tklab/hagward/lcextractor/scm/DBTools#public_void_storeRepositoryReaderResult(RepositoryReaderResult_result,String_dbName)', 'src/tklab/hagward/lcextractor/cli/Predictor#List[double[]]_predictContinuous(int_from,int_to,int_step,double_minSupport,double_minConfidence,boolean_average)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/cli/CommitRetriever#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/DBTools#private_RepositoryReaderResult_readResult(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBHandler#private_void_initTables(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBTools#private_void_writeResult(Statement_statement,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/cli/DBTools#public_RepositoryReaderResult_repositoryReaderResultFromDb(String_dbName)', 'src/tklab/hagward/lcextractor/scm/DBTools#public_void_storeRepositoryReaderResult(RepositoryReaderResult_result,String_dbName)', 'src/tklab/hagward/lcextractor/scm/Commit#public_Commit(RevCommit_revCommit)', 'src/tklab/hagward/lcextractor/scm/Commit#public_Commit(String_name,String_message)', 'src/tklab/hagward/lcextractor/scm/Commit#public_String_getMessage()', 'src/tklab/hagward/lcextractor/scm/Commit#public_String_getName()', 'src/tklab/hagward/lcextractor/scm/GitReader#private_boolean_processCommit(RevCommit_commit,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()']
# ['src/tklab/hagward/lcextractor/cli/CommitRetriever#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/DBHandler#private_void_initTables(Statement_statement)', 'src/tklab/hagward/lcextractor/cli/DBTools#private_void_writeResult(Statement_statement,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/scm/DBTools#public_void_storeRepositoryReaderResult(RepositoryReaderResult_result,String_dbName)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_Set[T]_keySet()', 'src/tklab/hagward/lcextractor/scm/MappedList#public_int_size()']
# ['src/tklab/hagward/lcextractor/cli/CommitRetriever#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/DBTools#public_void_storeRepositoryReaderResult(RepositoryReaderResult_result,String_dbName)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/GitReader#private_boolean_processCommit(RevCommit_commit,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/scm/GitReader#private_void_processDiffEntry(DiffEntry_diffEntry,RepositoryReaderResult_result)', 'src/tklab/hagward/lcextractor/scm/GitReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_RepositoryReaderResult_getFilesFromAllCommits()', 'src/tklab/hagward/lcextractor/RepositoryReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_newChangeset()', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)']
# ['src/tklab/hagward/lcextractor/cli/CommitRetriever#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predictor#List[double[]]_predictContinuous(int_from,int_to,int_step,double_minSupport,double_minConfidence,boolean_average)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_RepositoryReaderResult_getFilesFromAllCommits()', 'src/tklab/hagward/lcextractor/RepositoryReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/cli/Predictor#List[double[]]_predictContinuous(int_from,int_to,int_step,double_minSupport,double_minConfidence,boolean_average)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/cli/Predictor#public_RepositoryReaderResult_getData()', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_void_setRemoved(T_item)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/cli/Predictor#List[double[]]_predictContinuous(int_from,int_to,int_step,double_minSupport,double_minConfidence,boolean_average)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/cli/Predictor#List[double[]]_predictContinuous(int_start,int_stop,int_step,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(int_from,int_to,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/cli/Predictor#List[double[]]_predictContinuous(int_start,int_stop,int_step,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#PredictorResult_oldPredict(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#double[]_predictAverage(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_double[]_predictCommit(List[AssociationRule]_rules,Set[Integer]_commit)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_int[]_matchRules(Set[Integer]_changeset,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#public_void_printDebug(String_s)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/tklab/hagward/lcextractor/cli/Main#private_void_initialize(String_vcs,String_path)', 'src/tklab/hagward/lcextractor/cli/Main#private_void_parseArguments(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predictor#PredictorResult_oldPredict(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/coupling/EditableDiffEntry#public_EditableDiffEntry(String_newPath,ChangeType_changeType)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_boolean_applyFilter(String_msg)', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#boolean_isRemoved(String_path)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_SVNReader(String_svnUrl)']
# ['src/tklab/hagward/lcextractor/ArgumentParser#public_void_addOption(String_name,String_descr,String_init)', 'src/tklab/hagward/lcextractor/cli/Main#private_void_initialize(String_vcs,String_path)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)']
# ['src/tklab/hagward/lcextractor/cli/Main#private_void_initialize(String_vcs,String_path)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_boolean_setContains(Set[Integer]_changeset,int[]_items)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_int[]_matchRules(Set[Integer]_changeset,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/cli/Predictor#PredictorResult_oldPredict(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_LCExtractor()']
# ['src/tklab/hagward/lcextractor/cli/Main#private_String_formatRule(AssociationRule_rule,MappedList[String]_mapList)', 'src/tklab/hagward/lcextractor/cli/Main#private_void_initialize(String_vcs,String_path)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/GitReader#public_GitReader(File_pathToRepository)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_boolean_applyFilter(String_msg)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_RepositoryReaderResult_getFilesFromAllCommits()', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_boolean_isTrackingDeletedFiles()', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_boolean_isTrackingRenamedFiles()', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_boolean_isUsingInvertedMatching()', 'src/tklab/hagward/lcextractor/RepositoryReader#public_void_addMessageFilter(String_filter)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_void_setTrackDeletedFiles(boolean_trackDeletedFiles)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_void_setTrackRenamedFiles(boolean_trackRenamedFiles)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_void_setUseInvertedMatching(boolean_useInvertedMatching)', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_trim()', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_addToLastChangeset(String_path)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/cli/Predictor#private_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_boolean_isRInitialized()', 'src/tklab/hagward/lcextractor/LCExtractor#public_void_initR()']
# ['src/tklab/hagward/lcextractor/ArgumentParser#private_String[]_parseOption(String_arg)', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_ArgumentParser()', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_String_getUsageString()', 'src/tklab/hagward/lcextractor/ArgumentParser#public_void_addOption(String_name,String_descr,String_init)', 'src/tklab/hagward/lcextractor/ArgumentParser#public_void_parse(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Predictor#PredictorResult_oldPredict(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_PredictorResult(int_numCorrect,int_numIncorrect,int_numMissed,int_numRules)', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_String_toString()', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_double_getPrecision()', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_double_getRecall()', 'src/tklab/hagward/lcextractor/scm/MappedList#public_MappedList()']
# ['src/tklab/hagward/lcextractor/coupling/Predictor#private_boolean_setContains(Set[Integer]_changeset,int[]_items)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_int[]_matchRules(Set[Integer]_changeset,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/cli/Predictor#PredictorResult_oldPredict(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_String_toString()']
# ['src/tklab/hagward/lcextractor/cli/Main#private_String_formatRule(AssociationRule_rule,MappedList[String]_mapList)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/Predictor#private_boolean_setContains(Set[Integer]_changeset,int[]_items)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_int[]_matchRules(Set[Integer]_changeset,List[AssociationRule]_rules)', 'src/tklab/hagward/lcextractor/cli/Predictor#private_Predictor(RepositoryReaderResult_data,LCExtractor_lcExtractor)', 'src/tklab/hagward/lcextractor/cli/Predictor#PredictorResult_oldPredict(double_splittingPoint,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Predict#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_PredictorResult(int_numCorrect,int_numIncorrect,int_numMissed,int_numRules)', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_String_toString()', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_double_getPrecision()', 'src/tklab/hagward/lcextractor/cli/PredictorResult#public_double_getRecall()', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_AssociationRule(String[]_lhs,String[]_rhs,double[]_quality)', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_int[]_getLhs()', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_String[]_getRhs()', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/tklab/hagward/lcextractor/cli/Main#private_String_formatRule(AssociationRule_rule,MappedList[String]_mapList)', 'src/tklab/hagward/lcextractor/cli/Main#private_void_parseArguments(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)']
# ['src/tklab/hagward/lcextractor/cli/Main#private_void_parseArguments(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Main#private_void_initialize(String_vcs,String_path)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_String_toString()']
# ['src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_ensureLastChangesetEmpty()']
# ['src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_Integer_getIndex(T_item)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_MappedList()', 'src/tklab/hagward/lcextractor/scm/MappedList#public_String_toString()', 'src/tklab/hagward/lcextractor/scm/MappedList#public_T_getItem(int_index)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_int_addIfNotPresent(T_item)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_void_setRemoved(T_item)', 'src/tklab/hagward/lcextractor/scm/MappedList#public_void_setReplaced(T_oldItem,T_newItem)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#boolean_isRemoved(String_path)', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_addToLastChangeset(String_path)', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_deletePath(String_path)', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_ensureLastChangesetEmpty()', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_renamePath(String_oldPath,String_newPath)', 'src/tklab/hagward/lcextractor/scm/RepositoryReaderResult#public_void_trim()', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/cli/ArgumentParser#public_boolean_getArgAsBoolean(String_name)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)']
# ['src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_boolean_applyFilter(String_msg)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_void_setMessageFilter(String_filter,boolean_invertedMatching)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/ArgumentParser#private_String[]_parseOption(String_arg)', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#private_void_compileUsageString()', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_ArgumentParser()', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_String_getArgAsString(String_name)', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_String_getUsageString()', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_double_getArgAsDouble(String_name)', 'src/tklab/hagward/lcextractor/ArgumentParser#public_int_getArgAsInt(String_name)', 'src/tklab/hagward/lcextractor/ArgumentParser#public_void_addOption(String_name,String_descr,String_init)', 'src/tklab/hagward/lcextractor/ArgumentParser#public_void_parse(String[]_args)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_AssociationRule(String[]_lhs,String[]_rhs,double[]_quality)', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_int[]_getLhs()', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_String[]_getRhs()', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_String_toString()', 'src/tklab/hagward/lcextractor/AssociationRule#public_double_getConfidence()', 'src/tklab/hagward/lcextractor/AssociationRule#public_double_getLift()', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_double_getSupport()', 'src/tklab/hagward/lcextractor/coupling/EditableDiffEntry#public_EditableDiffEntry(String_newPath,ChangeType_changeType)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_LCExtractor()', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/LCExtractor#public_void_initR()', 'src/tklab/hagward/lcextractor/scm/GitReader#private_List[DiffEntry]_getCommitChanges(RevCommit_commit)', 'src/tklab/hagward/lcextractor/scm/GitReader#public_GitReader(File_pathToRepository)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_boolean_applyFilters(String_msg)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_void_printDebug(String_s)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_RepositoryReaderResult_getFilesFromAllCommits()', 'src/tklab/hagward/lcextractor/RepositoryReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/RepositoryReader#public_void_addMessageFilter(String_filter)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_void_addMessageFilters(List[String]_filters)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_SVNReader(String_svnUrl)']
# ['src/tklab/hagward/lcextractor/ArgumentParser#private_String[]_parseOption(String_arg)', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#private_void_compileUsageString()', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_ArgumentParser()', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_String_getArgAsString(String_name)', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_String_getUsageString()', 'src/tklab/hagward/lcextractor/cli/ArgumentParser#public_double_getArgAsDouble(String_name)', 'src/tklab/hagward/lcextractor/ArgumentParser#public_int_getArgAsInt(String_name)', 'src/tklab/hagward/lcextractor/ArgumentParser#public_void_addOption(String_name,String_descr,String_init)', 'src/tklab/hagward/lcextractor/ArgumentParser#public_void_parse(String[]_args)', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_String_toString()', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/coupling/LCExtractor#public_LCExtractor()', 'src/tklab/hagward/lcextractor/LCExtractor#public_void_initR()', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_SVNReader(String_svnUrl)']
# ['src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/RepositoryReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)']
# ['src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/coupling/AssociationRule#public_String_toString()', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_boolean_applyFilters(String_msg)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_RepositoryReaderResult_getFilesFromAllCommits()', 'src/tklab/hagward/lcextractor/RepositoryReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/RepositoryReader#public_void_addMessageFilter(String_filter)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_void_addMessageFilters(List[String]_filters)', 'src/tklab/hagward/lcextractor/RepositoryReaderResult#public_RepositoryReaderResult()', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/scm/GitReader#public_GitReader(File_pathToRepository)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#public_LCExtractor()', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_boolean_applyFilters(String_msg)', 'src/tklab/hagward/lcextractor/RepositoryReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_SVNReader(String_svnUrl)']
# ['src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/RepositoryReader#public_void_addMessageFilter(String_filter)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_void_addMessageFilters(List[String]_filters)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_SVNReader(String_svnUrl)']
# ['src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_RepositoryReaderResult_getFilesFromAllCommits()', 'src/tklab/hagward/lcextractor/RepositoryReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)']
# ['src/tklab/hagward/lcextractor/scm/GitReader#private_List[DiffEntry]_getCommitChanges(RevCommit_commit)', 'src/tklab/hagward/lcextractor/scm/GitReader#public_GitReader(File_pathToRepository)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_RepositoryReaderResult_getFilesFromCommits(String_start,String_stop,boolean_includeMessages)', 'src/tklab/hagward/lcextractor/scm/SVNReader#public_SVNReader(String_svnUrl)']
# ['src/tklab/hagward/lcextractor/scm/GitReader#public_GitReader(File_pathToRepository)', 'src/tklab/hagward/lcextractor/scm/GitReader#private_List[DiffEntry]_getCommitChanges(RevCommit_commit)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_void_printDebug(String_s)', 'src/LCExtractor#public_List[String]_getFilesInCommit(RevCommit_commit)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#public_RepositoryReaderResult_getFilesFromAllCommits()', 'src/tklab/hagward/lcextractor/LCExtractor#public_LCExtractor(File_pathToRepository)']
# ['src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_void_printDebug(String_s)', 'src/LCExtractor#public_List[String]_getFilesInCommit(RevCommit_commit)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#public_LCExtractor(File_pathToRepository)']
# ['src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)']
# ['src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)']
# ['src/tklab/hagward/lcextractor/coupling/LCExtractor#private_String_buildRString(List[Set[Integer]]_list,int_start,int_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#private_void_printDebug(String_s)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/cli/Main#public_void_main(String[]_args)', 'src/tklab/hagward/lcextractor/scm/RepositoryReader#protected_void_printDebug(String_s)', 'src/LCExtractor#public_List[String]_getFilesInCommit(RevCommit_commit)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#public_LCExtractor(File_pathToRepository)']
# ['src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)', 'src/tklab/hagward/lcextractor/LCExtractor#public_void_printDebug(String_s)']
# ['src/tklab/hagward/lcextractor/coupling/EditableDiffEntry#public_EditableDiffEntry(String_newPath,ChangeType_changeType)', 'src/LCExtractor#public_List[String]_getFilesInCommit(RevCommit_commit)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/LCExtractor#public_List[String]_getFilesInCommit(RevCommit_commit)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/tklab/hagward/lcextractor/coupling/AssociationRule#public_AssociationRule(String[]_lhs,String[]_rhs,double[]_quality)', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_int[]_getLhs()', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_String[]_getRhs()', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_String_toString()', 'src/tklab/hagward/lcextractor/AssociationRule#public_double_getConfidence()', 'src/tklab/hagward/lcextractor/AssociationRule#public_double_getLift()', 'src/tklab/hagward/lcextractor/coupling/AssociationRule#public_double_getSupport()']
# ['src/tklab/hagward/lcextractor/LCExtractor#public_LCExtractor(File_pathToRepository)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/LCExtractor#public_List[String]_getFilesInCommit(RevCommit_commit)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/LCExtractor#public_List[String]_getFilesInCommit(RevCommit_commit)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/LCExtractor#public_LCExtractor(File_pathToRepository)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
# ['src/LCExtractor#public_LCExtractor(File_pathToRepository)', 'src/tklab/hagward/lcextractor/GitReader#public_List[List[String]]_getFilesFromCommits(String_start,String_stop)', 'src/LCExtractor#public_List[String]_getFilesInCommit(RevCommit_commit)', 'src/tklab/hagward/lcextractor/LCExtractor#public_List[AssociationRule]_getLogicalCoupling(List[List[String]]_items,double_minSupport,double_minConfidence)']
